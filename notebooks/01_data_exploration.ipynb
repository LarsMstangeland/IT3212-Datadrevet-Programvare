# %% [markdown]
# # Data Exploration (10 points)
#
# This notebook covers data exploration tasks for the IT3212 Datadrevet Programvare course.
#
# ## Objectives:
# - Load and examine the structure of datasets
# - Perform basic statistical analysis
# - Create visualizations to understand data distribution
# - Identify patterns and relationships in the data
#
# ## Tasks:
# 1. Load the dataset(s)
# 2. Display basic information about the data (shape, types, etc.)
# 3. Generate summary statistics
# 4. Create visualizations for key variables
# 5. Document findings and insights

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for plots
plt.style.use('default')
sns.set_palette("husl")

# %%
# TODO: Load your dataset here
# df = pd.read_csv('../data/your_dataset.csv')

# %%
# TODO: Explore the structure of your data
# Add your data exploration code here
