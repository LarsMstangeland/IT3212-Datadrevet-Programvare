# %% [markdown]
# # Bonus Task: Dimensionality Reduction (Optional, 10 points)
#
# This notebook covers dimensionality reduction techniques for the IT3212 Datadrevet Programvare course.
#
# ## Objectives:
# - Apply Principal Component Analysis (PCA)
# - Implement t-SNE for visualization
# - Use Linear Discriminant Analysis (LDA)
# - Compare different dimensionality reduction techniques
# - Evaluate the impact on data and model performance
#
# ## Tasks:
# 1. Principal Component Analysis (PCA)
# 2. t-Distributed Stochastic Neighbor Embedding (t-SNE)
# 3. Linear Discriminant Analysis (LDA)
# 4. Feature selection techniques
# 5. Comparison of methods
# 6. Visualization of reduced dimensions

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import (
    SelectKBest, f_classif, RFE, SelectFromModel
)
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
# TODO: Load your split dataset from the previous step
# X_train = pd.read_csv('../data/X_train.csv')
# X_test = pd.read_csv('../data/X_test.csv')
# y_train = pd.read_csv('../data/y_train.csv')
# y_test = pd.read_csv('../data/y_test.csv')

# %%
# TODO: Apply PCA
# Determine optimal number of components
def apply_pca(X_train, X_test, n_components=None):
    """
    Apply PCA to training and test data
    """
    # Add your PCA implementation here
    pass

# %%
# TODO: Apply t-SNE for visualization
# Note: t-SNE is typically used for visualization, not for preprocessing
def apply_tsne(X, n_components=2):
    """
    Apply t-SNE for dimensionality reduction and visualization
    """
    # Add your t-SNE implementation here
    pass

# %%
# TODO: Apply LDA (for classification tasks)
def apply_lda(X_train, X_test, y_train):
    """
    Apply Linear Discriminant Analysis
    """
    # Add your LDA implementation here
    pass

# %%
# TODO: Feature selection techniques
# Implement univariate feature selection, RFE, and model-based selection
# Add your feature selection code here

# %%
# TODO: Visualize results
# Create plots to compare different dimensionality reduction techniques
# Add your visualization code here

# %%
# TODO: Evaluate impact on model performance
# Compare model performance before and after dimensionality reduction
# Add your evaluation code here
