# %% [markdown]
# # Handling Outliers (20 points)
#
# This notebook covers outlier detection and handling for the IT3212 Datadrevet Programvare course.
#
# ## Objectives:
# - Detect outliers using various statistical methods
# - Visualize outliers in the data
# - Decide on appropriate outlier treatment strategies
# - Implement outlier handling techniques
# - Evaluate the impact of outlier treatment
#
# ## Tasks:
# 1. Statistical outlier detection (IQR, Z-score, modified Z-score)
# 2. Visualization-based outlier identification
# 3. Machine learning-based outlier detection
# 4. Outlier treatment (removal, transformation, capping)
# 5. Impact assessment of outlier handling
# 6. Document decisions and rationale

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler

# %%
# TODO: Load your transformed dataset from the previous step
# df_transformed = pd.read_csv('../data/transformed_dataset.csv')

# %%
# TODO: Statistical outlier detection
# Implement IQR method
def detect_outliers_iqr(df, column):
    """
    Detect outliers using the IQR method
    """
    # Add your IQR outlier detection code here
    pass

# %%
# TODO: Z-score based outlier detection
def detect_outliers_zscore(df, column, threshold=3):
    """
    Detect outliers using Z-score method
    """
    # Add your Z-score outlier detection code here
    pass

# %%
# TODO: Visualize outliers
# Create box plots, scatter plots, and histograms to identify outliers
# Add your visualization code here

# %%
# TODO: Apply outlier treatment
# Implement your chosen outlier handling strategy
# Add your outlier treatment code here
