# %% [markdown]
# # Data Transformation (30 points)
#
# This notebook covers data transformation tasks for the IT3212 Datadrevet Programvare course.
#
# ## Objectives:
# - Apply feature engineering techniques
# - Normalize and scale numerical features
# - Encode categorical variables
# - Create derived features
# - Apply mathematical transformations
#
# ## Tasks:
# 1. Feature scaling and normalization
# 2. Categorical variable encoding (one-hot, label, target encoding)
# 3. Feature creation and engineering
# 4. Mathematical transformations (log, square root, etc.)
# 5. Binning and discretization
# 6. Validate transformed features

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import (
    StandardScaler, MinMaxScaler, RobustScaler,
    LabelEncoder, OneHotEncoder, OrdinalEncoder
)
from sklearn.feature_selection import SelectKBest, f_classif

# %%
# TODO: Load your cleaned dataset from the previous step
# df_cleaned = pd.read_csv('../data/cleaned_dataset.csv')

# %%
# TODO: Apply feature scaling
# Example: scaler = StandardScaler()
# Add your scaling code here

# %%
# TODO: Encode categorical variables
# Add your encoding code here

# %%
# TODO: Create new features
# Add your feature engineering code here
