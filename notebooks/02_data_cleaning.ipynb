# %% [markdown]
# # Data Cleaning (20 points)
#
# This notebook covers data cleaning tasks for the IT3212 Datadrevet Programvare course.
#
# ## Objectives:
# - Identify and handle missing values
# - Detect and correct data inconsistencies
# - Remove or fix invalid data entries
# - Standardize data formats
# - Document cleaning decisions and their rationale
#
# ## Tasks:
# 1. Assess data quality issues
# 2. Handle missing values (deletion, imputation, etc.)
# 3. Fix data type issues
# 4. Standardize categorical values
# 5. Remove duplicates
# 6. Validate cleaned data

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer, KNNImputer

# %%
# TODO: Load your dataset from the previous step
# df = pd.read_csv('../data/your_dataset.csv')

# %%
# TODO: Assess data quality
# Check for missing values, duplicates, and data type issues
# Add your data quality assessment code here

# %%
# TODO: Implement data cleaning procedures
# Add your data cleaning code here
